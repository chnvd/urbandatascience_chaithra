# %% [markdown]
# ## Module 3 Class activities
# This notebook is a starting point for the exercises and activities that we'll do in class.
#
# Before you attempt any of these activities, make sure to watch the video lectures for this module.

# %% [markdown]
# ### Joining tables
# Let's look at the spatial distribution of vaccine hesitancy, early in the pandemic.
#
# The CDC has a dataset at the county level, [available via Socrata](https://data.cdc.gov/Vaccinations/Vaccine-Hesitancy-for-COVID-19-County-and-local-es/q9mh-h2tw).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Import the vaccine hesitancy dataset into a dataframe. Call it <strong>hesitancy</strong>.
# </div>

# %% [markdown]
# *Hint*: Use the same approach as for the Seattle permits (class 2) or the Los Angeles housing (lecture 5). Just use a different URL.
#
# *Hint*: Add the `limit` keyword at the end of the URL to get more than 1000 rows. [See the example here](https://github.com/socrata/discuss/issues/145). There are 3,142 rows, according to the dataset's webpage, so you will be safe if you specify a limit of (say) 5000 rows.

# %%
# your code here
import json
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

url = 'https://data.cdc.gov/resource/q9mh-h2tw.json?$limit=5000'
r_cdc = requests.get(url)
hesitancy = pd.DataFrame(json.loads(r_cdc.text))

hesitancy.head()
# Out:
#   fips_code                 county_name    state estimated_hesitant
# 0      1123  Tallapoosa County, Alabama  ALABAMA             0.1806  \
# 1      1121   Talladega County, Alabama  ALABAMA             0.1783
# 2      1131      Wilcox County, Alabama  ALABAMA             0.1735
# 3      1129  Washington County, Alabama  ALABAMA             0.1735
# 4      1119      Sumter County, Alabama  ALABAMA             0.1808
#
#   estimated_hesitant_or_unsure estimated_strongly_hesitant
# 0                         0.24                      0.1383  \
# 1                        0.235                      0.1368
# 2                       0.2357                      0.1337
# 3                       0.2357                      0.1337
# 4                       0.2526                       0.139
#
#   social_vulnerability_index             svi_category
# 0                       0.89  Very High Vulnerability  \
# 1                       0.87  Very High Vulnerability
# 2                       0.93  Very High Vulnerability
# 3                       0.73       High Vulnerability
# 4                       0.96  Very High Vulnerability
#
#   ability_to_handle_a_covid      cvac_category  ...
# 0                      0.64       High Concern  ...  \
# 1                      0.84  Very High Concern  ...
# 2                      0.94  Very High Concern  ...
# 3                      0.82  Very High Concern  ...
# 4                      0.96  Very High Concern  ...
#
#   percent_non_hispanic_asian percent_non_hispanic_black
# 0                     0.0036                     0.2697  \
# 1                     0.0061                     0.3237
# 2                     0.0003                     0.6938
# 3                     0.0025                     0.2354
# 4                     0.0214                     0.7192
#
#   percent_non_hispanic_native percent_non_hispanic_white
# 0                           0                     0.6887  \
# 1                      0.0003                     0.6263
# 2                           0                     0.2684
# 3                           0                     0.6495
# 4                           0                     0.2481
#
#                                   geographical_point state_code
# 0  {'type': 'Point', 'coordinates': [-86.844516, ...         AL  \
# 1  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 2  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 3  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 4  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
#
#                                      county_boundary
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...  \
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
#                                       state_boundary
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...  \
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
#   :@computed_region_hjsp_umg2 :@computed_region_skr5_azej
# 0                          29                          94
# 1                          29                          94
# 2                          29                          94
# 3                          29                          94
# 4                          29                          94
#
# [5 rows x 23 columns]

# %% [markdown]
# Before we do any joins, let's look at some state-level summary statistics.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Create a dataframe with the state-level means of estimated_hesitant and the vaccination rate.
# </div>

# %% [markdown]
# *Hints*:
# - It might make more sense to weight each county by population, but let's not worry about that here.
# - The `percent_adults_fully` columm gives the vaccination rate (as of June 2021)
# - Use `groupby`!
# - Before you do any operations, you might need to convert the data type of the column. I recommend creating a new column, e.g. `df['newcol'] = df.oldcol.astype(float)`

# %%
# your code here
hesitancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   fips_code                      3142 non-null   object
#  1   county_name                    3142 non-null   object
#  2   state                          3142 non-null   object
#  3   estimated_hesitant             3142 non-null   object
#  4   estimated_hesitant_or_unsure   3142 non-null   object
#  5   estimated_strongly_hesitant    3142 non-null   object
#  6   social_vulnerability_index     3141 non-null   object
#  7   svi_category                   3141 non-null   object
#  8   ability_to_handle_a_covid      3142 non-null   object
#  9   cvac_category                  3142 non-null   object
#  10  percent_adults_fully           2864 non-null   object
#  11  percent_hispanic               3142 non-null   object
#  12  percent_non_hispanic_american  3142 non-null   object
#  13  percent_non_hispanic_asian     3142 non-null   object
#  14  percent_non_hispanic_black     3142 non-null   object
#  15  percent_non_hispanic_native    3142 non-null   object
#  16  percent_non_hispanic_white     3142 non-null   object
#  17  geographical_point             3142 non-null   object
#  18  state_code                     3142 non-null   object
#  19  county_boundary                3141 non-null   object
#  20  state_boundary                 3141 non-null   object
#  21  :@computed_region_hjsp_umg2    3142 non-null   object
#  22  :@computed_region_skr5_azej    3142 non-null   object
# dtypes: object(23)
# memory usage: 564.7+ KB

# %%
# your code here  Create a dataframe with the state-level means of estimated_hesitant and the vaccination rate.
hesitancy['new_estimated_hesitant']=hesitancy.estimated_hesitant.astype(float)
hesitancy['new_percent_adults_fully']=hesitancy.percent_adults_fully.astype(float)
df_hesitancy = hesitancy.groupby('state_code')[['new_estimated_hesitant','new_percent_adults_fully']].mean()
df_hesitancy.head()
# Out:
#             new_estimated_hesitant  new_percent_adults_fully
# state_code
# AK                        0.217386                  0.582296
# AL                        0.173507                  0.320851
# AR                        0.212123                  0.338800
# AZ                        0.159240                  0.504733
# CA                        0.072274                  0.506820

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Create a scatter plot of hesitancy vs vaccination rates.
# </div>

# %%
# your code here

df_hesitancy.plot.scatter(x='new_estimated_hesitant', 
                          y='new_percent_adults_fully',
                          s=50
                         )
# Out:
# <Axes: xlabel='new_estimated_hesitant', ylabel='new_percent_adults_fully'>

# %% [markdown]
# ## Joining
# Now let's do a join.
# It looks like the county boundaries are in our original dataframe, but in a weird format. We could try and parse them. But instead, let's get the county boundaries and total population using `cenpy`.
#
# We'll just do one state, in order to reduce the sizes of the files for this exercise.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Get a geodataframe of the county boundaries and population totals for a state of your choice, using cenpy.
# </div>

# %% [markdown]
# *Hints*:
# * The `from_state`, rather than `from_county` will be helpful. See the [docs](http://cenpy-devs.github.io/cenpy/generated/cenpy.products.ACS.from_state.html).
# * You'll need to specify the state (e.g. "California") and the level (use "county").
# * A small state will download faster!
# * The population variable is B01001_001E

# %%
import cenpy
acs = cenpy.products.ACS()
censusDf = acs.from_state('New York', variables='B01001_001E', level='county')
censusDf.head()
# Out:
# /Users/chaithra/opt/anaconda3/envs/uds/lib/python3.10/site-packages/cenpy/products.py:767: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   return self._from_name(state, variables, level, "States", **kwargs)
#    GEOID                                           geometry  B01001_001E
# 0  36109  POLYGON ((-8525513.300 5243712.570, -8525574.4...     102642.0  \
# 1  36057  POLYGON ((-8320029.090 5311715.380, -8320181.4...      49302.0
# 2  36085  POLYGON ((-8266483.970 4938804.910, -8266483.9...     474893.0
# 3  36033  POLYGON ((-8314395.100 5614109.600, -8314401.6...      50477.0
# 4  36005  POLYGON ((-8230256.490 4995020.410, -8230042.4...    1435068.0
#
#                           NAME state county
# 0    Tompkins County, New York    36    109
# 1  Montgomery County, New York    36    057
# 2    Richmond County, New York    36    085
# 3    Franklin County, New York    36    033
# 4       Bronx County, New York    36    005

# %%
censusDf.set_index('GEOID')
hesitancy.set_index('fips_code')
joineddf=censusDf.join(hesitancy, rsuffix='_hesitancy', how='left')
joineddf.head()
# Out:
#    GEOID                                           geometry  B01001_001E
# 0  36109  POLYGON ((-8525513.300 5243712.570, -8525574.4...     102642.0  \
# 1  36057  POLYGON ((-8320029.090 5311715.380, -8320181.4...      49302.0
# 2  36085  POLYGON ((-8266483.970 4938804.910, -8266483.9...     474893.0
# 3  36033  POLYGON ((-8314395.100 5614109.600, -8314401.6...      50477.0
# 4  36005  POLYGON ((-8230256.490 4995020.410, -8230042.4...    1435068.0
#
#                           NAME state county fips_code
# 0    Tompkins County, New York    36    109      1123  \
# 1  Montgomery County, New York    36    057      1121
# 2    Richmond County, New York    36    085      1131
# 3    Franklin County, New York    36    033      1129
# 4       Bronx County, New York    36    005      1119
#
#                   county_name state_hesitancy estimated_hesitant  ...
# 0  Tallapoosa County, Alabama         ALABAMA             0.1806  ...  \
# 1   Talladega County, Alabama         ALABAMA             0.1783  ...
# 2      Wilcox County, Alabama         ALABAMA             0.1735  ...
# 3  Washington County, Alabama         ALABAMA             0.1735  ...
# 4      Sumter County, Alabama         ALABAMA             0.1808  ...
#
#   percent_non_hispanic_native percent_non_hispanic_white
# 0                           0                     0.6887  \
# 1                      0.0003                     0.6263
# 2                           0                     0.2684
# 3                           0                     0.6495
# 4                           0                     0.2481
#
#                                   geographical_point state_code
# 0  {'type': 'Point', 'coordinates': [-86.844516, ...         AL  \
# 1  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 2  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 3  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
# 4  {'type': 'Point', 'coordinates': [-86.844516, ...         AL
#
#                                      county_boundary
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...  \
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
#                                       state_boundary
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...  \
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...
#
#   :@computed_region_hjsp_umg2 :@computed_region_skr5_azej
# 0                          29                          94  \
# 1                          29                          94
# 2                          29                          94
# 3                          29                          94
# 4                          29                          94
#
#   new_estimated_hesitant new_percent_adults_fully
# 0                 0.1806                    0.305
# 1                 0.1783                    0.265
# 2                 0.1735                    0.394
# 3                 0.1735                    0.308
# 4                 0.1808                    0.362
#
# [5 rows x 31 columns]

# %%
joineddf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   GEOID                          62 non-null     object
#  1   geometry                       62 non-null     geometry
#  2   B01001_001E                    62 non-null     float64
#  3   NAME                           62 non-null     object
#  4   state                          62 non-null     object
#  5   county                         62 non-null     object
#  6   fips_code                      62 non-null     object
#  7   county_name                    62 non-null     object
#  8   state_hesitancy                62 non-null     object
#  9   estimated_hesitant             62 non-null     object
#  10  estimated_hesitant_or_unsure   62 non-null     object
#  11  estimated_strongly_hesitant    62 non-null     object
#  12  social_vulnerability_index     62 non-null     object
#  13  svi_category                   62 non-null     object
#  14  ability_to_handle_a_covid      62 non-null     object
#  15  cvac_category                  62 non-null     object
#  16  percent_adults_fully           60 non-null     object
#  17  percent_hispanic               62 non-null     object
#  18  percent_non_hispanic_american  62 non-null     object
#  19  percent_non_hispanic_asian     62 non-null     object
#  20  percent_non_hispanic_black     62 non-null     object
#  21  percent_non_hispanic_native    62 non-null     object
#  22  percent_non_hispanic_white     62 non-null     object
#  23  geographical_point             62 non-null     object
#  24  state_code                     62 non-null     object
#  25  county_boundary                62 non-null     object
#  26  state_boundary                 62 non-null     object
#  27  :@computed_region_hjsp_umg2    62 non-null     object
#  28  :@computed_region_skr5_azej    62 non-null     object
#  29  new_estimated_hesitant         62 non-null     float64
#  30  new_percent_adults_fully       60 non-null     float64
# dtypes: float64(3), geometry(1), object(27)
# memory usage: 15.1+ KB

# %% [markdown]
# You should have a `GEOID` column in your `censusDf`, as well as a geometry column.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Join the covid dataframe to your census dataframe.</div>

# %% [markdown]
# *Hints:*:
# * Look at which column gives the county FIPS code in each dataframe.
# * Do the data types match? Anything else you need to clean up before joining?
# * It might be helpful to do a left join from the census dataframe. That means that you will automatically drop the data for counties in other states.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Create some county-level maps and other simple analyses.
# </div>

# %% [markdown]
# The [geopandas documentation](https://geopandas.org/en/stable/docs/user_guide/mapping.html) has some useful tips.
#
# Hint: make sure your column is numeric before you plot it!

# %%
# your code here
joineddf.plot('estimated_hesitant')
#hesitancy['new_estimated_hesitant']=hesitancy.estimated_hesitant.astype(float)
#hesitancy['new_percent_adults_fully']=hesitancy.percent_adults_fully.astype(float)
# Out:
# <Axes: >

# %%
def addone(x):
    return x+1

df = pd.DataFrame([1,3,5,7,0], columns=['number'])
df

# %%
df['nplusone']=df.number.apply(addone)
df
#apply works for a column where you want to do a function on
# unique, is_unique; first one lists out all unique values, second one checks if all values are unique or not.

# %%
df['nplustwo']=df.number.apply(lambda x: x+1)
df
#df['nplustwo']=df.number.apply(lambda x: x['column']+1, axis=1); specificy column header and axis of the column where you are doing that.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>What you should have learned</h3>
# <ul>
#   <li>Gain more practice with the APIs</li>
#   <li>Understand basic data cleaning operations, such as converting strings to numeric fields.</li>
#   <li>Understand how to compute group-level means and other summary statistics.</li>
#     <li>Understand how to join tables on a common column.</li>
# </ul>
# </div>
