# %% [markdown]
# # Spatial clusters
# ## Lecture objectives
# 1. Adapt the idea of k-means cluster analysis to spatial clusters
# 2. Provide more practice with k-means clustering and data wrangling
#
# The principles of clustering that we discussed in the previous lecture apply to identify clusters in space. The difference: we just cluster on the `x` and `y` coordinates rather than non-spatial variables such as voting on a particular proposition.
#
# Let's look at [clusters of marijuana dispensaries](https://data.lacity.org/Administration-Finance/Medical-Marijuana-Collective-Map/rv73-2zf4) in LA.

# %%
import pandas as pd
import requests
import json

url = 'https://data.lacity.org/resource/rv73-2zf4.json'
r = requests.get(url)
mdf = pd.DataFrame(json.loads(r.content))
mdf.head()
# Out:
#      zip_code :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv  \
# 0  91605-4217                        8888                         163
# 1  91311-2056                         NaN                         NaN
# 2  90033-3960                       23450                         522
# 3  90065-3937                       24030                         376
# 4  93286-9441                         NaN                         NaN
#
#               city :@computed_region_kqwf_mjcx     business_name  \
# 0  NORTH HOLLYWOOD                           5  VERDANT MOON LLC
# 1       CHATSWORTH                         NaN   KATHARINE MASON
# 2      LOS ANGELES                           9       ERICK MEDEL
# 3      LOS ANGELES                          11   JONATHAN M FINE
# 4         WOODLAKE                         NaN     NABIFIVE, LLC
#
#   :@computed_region_2dna_qi2s   naics     primary_naics_description  \
# 0                          71  888888  Medical Marijuana Collective
# 1                         NaN  888888  Medical Marijuana Collective
# 2                          38  888888  Medical Marijuana Collective
# 3                          92  888888  Medical Marijuana Collective
# 4                         NaN  888888  Medical Marijuana Collective
#
#         location_description  ...        street_address  \
# 0      7347 ETHEL 91605-4217  ...     7347 ETHEL AVENUE
# 1    10330 LARWIN 91311-2056  ...   10330 LARWIN AVENUE
# 2        2209 2nd 90033-3960  ...     2209 E 2ND STREET
# 3  4316 GLENALBYN 90065-3937  ...  4316 GLENALBYN DRIVE
# 4     1093 DELTHA 93286-9441  ...  1093 W DELTHA AVENUE
#
#        location_start_date   location_account council_district  \
# 0  2022-01-01T00:00:00.000  0003370267-0001-3                2
# 1  2018-02-12T00:00:00.000  0003368901-0001-3               12
# 2  2019-01-03T00:00:00.000  0003364966-0001-9               14
# 3  2014-01-10T00:00:00.000  0003362130-0001-1                1
# 4  2023-01-01T00:00:00.000  0003356201-0001-5                0
#
#                                           location_1     dba_name  \
# 0  {'latitude': '34.2044', 'human_address': '{"ad...          NaN
# 1                                                NaN  VALKYRIE 13
# 2  {'latitude': '34.0435', 'human_address': '{"ad...          NaN
# 3  {'latitude': '34.0963', 'human_address': '{"ad...          NaN
# 4                                                NaN          NaN
#
#   :@computed_region_ur2y_g4cx mailing_city mailing_zip_code mailing_address
# 0                         NaN          NaN              NaN             NaN
# 1                         NaN          NaN              NaN             NaN
# 2                         NaN          NaN              NaN             NaN
# 3                          13          NaN              NaN             NaN
# 4                         NaN          NaN              NaN             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Note the lat /lon information is a dictionary in the `location_1` column.

# %%
mdf.location_1.iloc[0]
# Out:
# {'latitude': '34.2044',
#  'human_address': '{"address": "", "city": "", "state": "", "zip": ""}',
#  'needs_recoding': False,
#  'longitude': '-118.4187'}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Exercise:</strong> Extract the lat/lon information from the <strong>location_1</strong> column and place it in two new columns
# </div>

# %%
mdf['lat'] = mdf.location_1.apply(lambda x: float(x['latitude']))
mdf['lon'] = mdf.location_1.apply(lambda x: float(x['longitude']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mdf['lat'] = mdf.location_1.apply(lambda x: float(x['latitude']))
#       2 mdf['lon'] = mdf.location_1.apply(lambda x: float(x['longitude']))
#
# File ~/opt/anaconda3/envs/uds/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/envs/uds/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/opt/anaconda3/envs/uds/lib/python3.10/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/envs/uds/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 1, in <lambda>(x)
# ----> 1 mdf['lat'] = mdf.location_1.apply(lambda x: float(x['latitude']))
#       2 mdf['lon'] = mdf.location_1.apply(lambda x: float(x['longitude']))
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# What row is causing this problem? Let's look at them?

# %%
mdf.location_1.head(20)
# Out:
# 0     {'latitude': '34.2044', 'human_address': '{"ad...
# 2     {'latitude': '34.0435', 'human_address': '{"ad...
# 3     {'latitude': '34.0963', 'human_address': '{"ad...
# 5     {'latitude': '34.1584', 'human_address': '{"ad...
# 6     {'latitude': '33.7796', 'human_address': '{"ad...
# 7     {'latitude': '34.2288', 'human_address': '{"ad...
# 8     {'latitude': '34.3117', 'human_address': '{"ad...
# 9     {'latitude': '34.0239', 'human_address': '{"ad...
# 10    {'latitude': '33.9417', 'human_address': '{"ad...
# 11    {'latitude': '34.0373', 'human_address': '{"ad...
# 12    {'latitude': '34.2427', 'human_address': '{"ad...
# 13    {'latitude': '34.0495', 'human_address': '{"ad...
# 14    {'latitude': '33.9616', 'human_address': '{"ad...
# 15    {'latitude': '33.7974', 'human_address': '{"ad...
# 16    {'latitude': '34.1793', 'human_address': '{"ad...
# 17    {'latitude': '34.026', 'human_address': '{"add...
# 18    {'latitude': '34.1661', 'human_address': '{"ad...
# 19    {'latitude': '34.0371', 'human_address': '{"ad...
# 20    {'latitude': '34.1646', 'human_address': '{"ad...
# 21    {'latitude': '34.014', 'human_address': '{"add...
# Name: location_1, dtype: object

# %% [markdown]
# OK, we need to drop the Null values for this column.

# %%
mdf.dropna(subset='location_1', inplace=True)
mdf['lat'] = mdf.location_1.apply(lambda x: float(x['latitude']))
mdf['lon'] = mdf.location_1.apply(lambda x: float(x['longitude']))

# %% [markdown]
# Let's have a look at the columns we just created.

# %%
mdf[['lat','lon']].describe()
# Out:
#               lat         lon
# count  673.000000  673.000000
# mean    33.422281 -115.704916
# std      4.895810   17.872825
# min      0.000000 -124.071900
# 25%     34.019400 -118.444900
# 50%     34.064700 -118.348000
# 75%     34.202400 -118.252100
# max     40.906800   33.797400

# %% [markdown]
# It looks like there are some errors in the input data. Some have a latitude and/or longitude of zero! There are also some with locations with improbable values.
#
# Let's crudely limit the dataset to those in Los Angeles. I eyeballed the lat/lon limits from a map.
#
# Then we can convert to a GeoDataFrame.

# %%
mdf = mdf[(mdf.lat>=33.6) & (mdf.lat<=34.8)]
mdf = mdf[(mdf.lon>=-119.0) & (mdf.lon<=-117.6)]

import geopandas as gpd

mgdf = gpd.GeoDataFrame(mdf, 
            geometry = gpd.points_from_xy(mdf.lon, mdf.lat), 
            crs='EPSG:4326')
mgdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# Now let's cluster. Again, we'd want to experiment with `K`, but let's identify 20 clusters to start.
#
# Technically, we should reproject before we cluster because a degree of latitude is not the same distance as a degree of longitude. But we can overlook that for simplicity's sake.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=20, random_state=1).fit(mgdf[['lat','lon']])
mgdf['cluster_id'] = kmeans.labels_
mgdf.head()
# Out:
# /Users/chaithra/opt/anaconda3/envs/uds/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#      zip_code :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv  \
# 0  91605-4217                        8888                         163
# 2  90033-3960                       23450                         522
# 3  90065-3937                       24030                         376
# 5  91436-1887                       19737                         326
# 6  90744-5833                        3350                         963
#
#               city :@computed_region_kqwf_mjcx     business_name  \
# 0  NORTH HOLLYWOOD                           5  VERDANT MOON LLC
# 2      LOS ANGELES                           9       ERICK MEDEL
# 3      LOS ANGELES                          11   JONATHAN M FINE
# 5           ENCINO                           6    SOMMER RAY LLC
# 6       WILMINGTON                          15    SHAHRAM TIZABI
#
#   :@computed_region_2dna_qi2s   naics     primary_naics_description  \
# 0                          71  888888  Medical Marijuana Collective
# 2                          38  888888  Medical Marijuana Collective
# 3                          92  888888  Medical Marijuana Collective
# 5                          62  888888  Medical Marijuana Collective
# 6                          15  888888  Medical Marijuana Collective
#
#         location_description  ...  \
# 0      7347 ETHEL 91605-4217  ...
# 2        2209 2nd 90033-3960  ...
# 3  4316 GLENALBYN 90065-3937  ...
# 5   16633 Ventura 91436-1887  ...
# 6       735 Broad 90744-5833  ...
#
#                                           location_1 dba_name  \
# 0  {'latitude': '34.2044', 'human_address': '{"ad...      NaN
# 2  {'latitude': '34.0435', 'human_address': '{"ad...      NaN
# 3  {'latitude': '34.0963', 'human_address': '{"ad...      NaN
# 5  {'latitude': '34.1584', 'human_address': '{"ad...      NaN
# 6  {'latitude': '33.7796', 'human_address': '{"ad...      NaN
#
#   :@computed_region_ur2y_g4cx mailing_city mailing_zip_code  \
# 0                         NaN          NaN              NaN
# 2                         NaN          NaN              NaN
# 3                          13          NaN              NaN
# 5                           6       ENCINO       91436-1887
# 6                         NaN          NaN              NaN
#
#                   mailing_address      lat       lon  \
# 0                             NaN  34.2044 -118.4187
# 2                             NaN  34.0435 -118.2128
# 3                             NaN  34.0963 -118.2096
# 5  16633 VENTURA BLVD SUITE #1450  34.1584 -118.4955
# 6                             NaN  33.7796 -118.2615
#
#                       geometry cluster_id
# 0  POINT (-118.41870 34.20440)          5
# 2  POINT (-118.21280 34.04350)         13
# 3  POINT (-118.20960 34.09630)         17
# 5  POINT (-118.49550 34.15840)          5
# 6  POINT (-118.26150 33.77960)          4
#
# [5 rows x 25 columns]

# %% [markdown]
# And map them! Again, this is almost identical code to what we used before. But let's ditch the legend because there are lots of clusters and the number is not as relevant.

# %%
import matplotlib.pyplot as plt
import contextily as ctx

fig, ax = plt.subplots(figsize=(5,5))
mgdf.to_crs('EPSG:3857').plot('cluster_id', categorical=True, legend=False, 
                                   ax=ax, alpha=0.4)

ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)
ax.set_title('Dispensary clusters', fontsize=10)                           
#ax.set_ylim([3.98e6, 4.14e6])
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# We could also map the centroid of each cluster. But I'll leave that for you as an exercise.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Exercise:</strong> Map the centroid of each cluster. <em>Hint</em>: The raw lat/lon values are found in <strong>kmeans.cluster_centers_</strong>.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Key Takeaways</h3>
# <ul>
#     <li>Spatial clusters work in a very similar way to non-spatial clusters.</li>
#     <li>They can identify different groupings and/or hotspots.</li>
#
# </ul>
# </div>
